# %%
import numpy as np
import pandas as pd

# %%
#help(pd.DataFrame)

# %%
np.random.seed(101)
mydata = np.random.randint(0,90,(4,3))
mydata
# Out:
# array([[11, 81, 70],
#        [63, 87, 75],
#        [ 9, 77, 40],
#        [ 4, 63, 40]])

# %%
myindex = ['RJ','HP','TN','NL']
mycolumns = ['Jan','Feb','Mar']

# %%
df = pd.DataFrame(data = mydata)
df
# Out:
#     0   1   2
# 0  11  81  70
# 1  63  87  75
# 2   9  77  40
# 3   4  63  40

# %%
df_labelled = pd.DataFrame(data = mydata,index=myindex,columns = mycolumns)
df_labelled
# Out:
#     Jan  Feb  Mar
# RJ   11   81   70
# HP   63   87   75
# TN    9   77   40
# NL    4   63   40

# %%
df_labelled.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, RJ to NL
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 128.0+ bytes

# %% [markdown]
# ###### Reading a CSV file into a DataFrame

# %%
df = pd.read_csv('tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ###### Basic Information from the DataFrame

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.sample(2)
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 169       10.63  2.0  Female    Yes  Sat  Dinner     2              5.32
# 161       12.66  2.5    Male     No  Sun  Dinner     2              6.33
#
#           Payer Name         CC Number Payment ID
# 169         Amy Hill  3536332481454019    Sat1788
# 161  Brandon Oconnor  4406882156920533    Sun5879

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
len(df)
# Out:
# 244

# %%
df.shape
# Out:
# (244, 11)

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# #### Indexing and Selection

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %% [markdown]
# ###### Grab a Single Column

# %%
df['Payer Name']
# Out:
# 0      Christy Cunningham
# 1          Douglas Tucker
# 2          Travis Walters
# 3        Nathaniel Harris
# 4            Tonya Carter
#               ...
# 239         Michael Avila
# 240        Monica Sanders
# 241            Keith Wong
# 242          Dennis Dixon
# 243       Michelle Hardin
# Name: Payer Name, Length: 244, dtype: object

# %%
type(df['Payer Name'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ###### Grab multiple columns

# %%
df[['Payer Name','total_bill','tip']] #python list of column names
# Out:
#              Payer Name  total_bill   tip
# 0    Christy Cunningham       16.99  1.01
# 1        Douglas Tucker       10.34  1.66
# 2        Travis Walters       21.01  3.50
# 3      Nathaniel Harris       23.68  3.31
# 4          Tonya Carter       24.59  3.61
# ..                  ...         ...   ...
# 239       Michael Avila       29.03  5.92
# 240      Monica Sanders       27.18  2.00
# 241          Keith Wong       22.67  2.00
# 242        Dennis Dixon       17.82  1.75
# 243     Michelle Hardin       18.78  3.00
#
# [244 rows x 3 columns]

# %%
type(df[['Payer Name','total_bill']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608

# %%
df['tip_percentage'] = round(df['tip']*100/df['total_bill'],3)

# %%
df.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
#
#            Payer Name         CC Number Payment ID  tip_percentage
# 0  Christy Cunningham  3560325168603410    Sun2959           5.945
# 1      Douglas Tucker  4478071379779230    Sun4608          16.054

# %% [markdown]
# ###### Removing Column(s)

# %%
df = df.drop('tip_percentage',axis=1) #, inplace=True)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.drop(['total_bill','sex','smoker'],axis=1).head()
# Out:
#     tip  day    time  size  price_per_person          Payer Name  \
# 0  1.01  Sun  Dinner     2              8.49  Christy Cunningham
# 1  1.66  Sun  Dinner     3              3.45      Douglas Tucker
# 2  3.50  Sun  Dinner     3              7.00      Travis Walters
# 3  3.31  Sun  Dinner     2             11.84    Nathaniel Harris
# 4  3.61  Sun  Dinner     4              6.15        Tonya Carter
#
#           CC Number Payment ID
# 0  3560325168603410    Sun2959
# 1  4478071379779230    Sun4608
# 2  6011812112971322    Sun4458
# 3  4676137647685994    Sun5260
# 4  4832732618637221    Sun2251

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# #### Index Basics

# %%
df = df.set_index('Payment ID')
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.reset_index()
df.head()
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
# 3    Sun5260       23.68  3.31    Male     No  Sun  Dinner     2
# 4    Sun2251       24.59  3.61  Female     No  Sun  Dinner     4
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322
# 3             11.84    Nathaniel Harris  4676137647685994
# 4              6.15        Tonya Carter  4832732618637221

# %% [markdown]
# ###### Grab a single row

# %%
df = df.set_index('Payment ID')
df
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Sat17            17.82  1.75    Male     No   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
#integer based
df.iloc[242]
# Out:
# total_bill                  17.82
# tip                          1.75
# sex                          Male
# smoker                         No
# day                           Sat
# time                       Dinner
# size                            2
# price_per_person             8.91
# Payer Name           Dennis Dixon
# CC Number           4375220550950
# Name: Sat17, dtype: object

# %%
#label based
df.loc['Sat17']
# Out:
# total_bill                  17.82
# tip                          1.75
# sex                          Male
# smoker                         No
# day                           Sat
# time                       Dinner
# size                            2
# price_per_person             8.91
# Payer Name           Dennis Dixon
# CC Number           4375220550950
# Name: Sat17, dtype: object

# %% [markdown]
# ###### Grab Multiple Rows

# %%
df.iloc[8:21]
# Out:
#             total_bill   tip     sex smoker  day    time  size  \
# Payment ID
# Sun6820          15.04  1.96    Male     No  Sun  Dinner     2
# Sun3775          14.78  3.23    Male     No  Sun  Dinner     2
# Sun2546          10.27  1.71    Male     No  Sun  Dinner     2
# Sun6686          35.26  5.00  Female     No  Sun  Dinner     4
# Sun1300          15.42  1.57    Male     No  Sun  Dinner     2
# Sun2971          18.43  3.00    Male     No  Sun  Dinner     4
# Sun3848          14.83  3.02  Female     No  Sun  Dinner     2
# Sun1878          21.58  3.92    Male     No  Sun  Dinner     2
# Sun9715          10.33  1.67  Female     No  Sun  Dinner     3
# Sun2998          16.29  3.71    Male     No  Sun  Dinner     3
# Sun2789          16.97  3.50  Female     No  Sun  Dinner     3
# Sat9213          20.65  3.35    Male     No  Sat  Dinner     3
# Sat1709          17.92  4.08    Male     No  Sat  Dinner     2
#
#             price_per_person        Payer Name         CC Number
# ...

# %%
df.loc[['Sat17','Sat1709','Sat9213','Sun1878']]
# Out:
#             total_bill   tip   sex smoker  day    time  size  \
# Payment ID
# Sat17            17.82  1.75  Male     No  Sat  Dinner     2
# Sat1709          17.92  4.08  Male     No  Sat  Dinner     2
# Sat9213          20.65  3.35  Male     No  Sat  Dinner     3
# Sun1878          21.58  3.92  Male     No  Sun  Dinner     2
#
#             price_per_person      Payer Name         CC Number
# Payment ID
# Sat17                   8.91    Dennis Dixon     4375220550950
# Sat1709                 8.96     Thomas Rice  4403296224639756
# Sat9213                 6.88   Timothy Oneal  6568069240986485
# Sun1878                10.79  Matthew Reilly   180073029785069

# %% [markdown]
# ##### Remove Rows

# %%
df.drop('Sat17',axis=0)
# Out:
#             total_bill   tip     sex smoker   day    time  size  \
# Payment ID
# Sun2959          16.99  1.01  Female     No   Sun  Dinner     2
# Sun4608          10.34  1.66    Male     No   Sun  Dinner     3
# Sun4458          21.01  3.50    Male     No   Sun  Dinner     3
# Sun5260          23.68  3.31    Male     No   Sun  Dinner     2
# Sun2251          24.59  3.61  Female     No   Sun  Dinner     4
# ...                ...   ...     ...    ...   ...     ...   ...
# Sat9777          35.83  4.67  Female     No   Sat  Dinner     3
# Sat2657          29.03  5.92    Male     No   Sat  Dinner     3
# Sat1766          27.18  2.00  Female    Yes   Sat  Dinner     2
# Sat3880          22.67  2.00    Male    Yes   Sat  Dinner     2
# Thur672          18.78  3.00  Female     No  Thur  Dinner     2
#
#             price_per_person          Payer Name         CC Number
# Payment ID
# Sun2959                 8.49  Christy Cunningham  3560325168603410
# ...

# %%
df = df.reset_index()
df.head(3)
# Out:
#   Payment ID  total_bill   tip     sex smoker  day    time  size  \
# 0    Sun2959       16.99  1.01  Female     No  Sun  Dinner     2
# 1    Sun4608       10.34  1.66    Male     No  Sun  Dinner     3
# 2    Sun4458       21.01  3.50    Male     No  Sun  Dinner     3
#
#    price_per_person          Payer Name         CC Number
# 0              8.49  Christy Cunningham  3560325168603410
# 1              3.45      Douglas Tucker  4478071379779230
# 2              7.00      Travis Walters  6011812112971322

# %%
df1 = df.drop(0,axis=0)
df1
# Out:
#     Payment ID  total_bill   tip     sex smoker   day    time  size  \
# 1      Sun4608       10.34  1.66    Male     No   Sun  Dinner     3
# 2      Sun4458       21.01  3.50    Male     No   Sun  Dinner     3
# 3      Sun5260       23.68  3.31    Male     No   Sun  Dinner     2
# 4      Sun2251       24.59  3.61  Female     No   Sun  Dinner     4
# 5      Sun9679       25.29  4.71    Male     No   Sun  Dinner     4
# ..         ...         ...   ...     ...    ...   ...     ...   ...
# 239    Sat2657       29.03  5.92    Male     No   Sat  Dinner     3
# 240    Sat1766       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241    Sat3880       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242      Sat17       17.82  1.75    Male     No   Sat  Dinner     2
# 243    Thur672       18.78  3.00  Female     No  Thur  Dinner     2
#
#      price_per_person        Payer Name         CC Number
# 1                3.45    Douglas Tucker  4478071379779230
# ...

# %%
#help(pd.concat)
