# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chennai = pd.read_csv('chennai_reservoir_levels.csv')
chennai.tail()
# Out:
#             Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM
# 5642  13-06-2019    30.0         0.0       0.0              1.0
# 5643  14-06-2019    28.0         0.0       0.0              1.0
# 5644  15-06-2019    27.0         0.0       0.0              1.0
# 5645  16-06-2019    26.0         0.0       0.0              1.0
# 5646  17-06-2019    25.0         0.0       0.0              1.0

# %%
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   object
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 220.7+ KB

# %%
chennai['Date'] = pd.to_datetime(chennai['Date'], format = '%d-%m-%Y')
chennai.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             5647 non-null   datetime64[ns]
#  1   POONDI           5647 non-null   float64
#  2   CHOLAVARAM       5647 non-null   float64
#  3   REDHILLS         5647 non-null   float64
#  4   CHEMBARAMBAKKAM  5647 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 220.7 KB

# %%
chennai['Year'] = chennai['Date'].apply(lambda x : x.year)
chennai['Month'] = chennai['Date'].apply(lambda x : x.month)

# %%
chennai.head()
# Out:
#         Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year  Month
# 0 2004-01-01     3.9         0.0     268.0              0.0  2004      1
# 1 2004-01-02     3.9         0.0     268.0              0.0  2004      1
# 2 2004-01-03     3.9         0.0     267.0              0.0  2004      1
# 3 2004-01-04     3.9         0.0     267.0              0.0  2004      1
# 4 2004-01-05     3.8         0.0     267.0              0.0  2004      1

# %%
chennai.columns
# Out:
# Index(['Date', 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM', 'Year',
#        'Month'],
#       dtype='object')

# %%
chennai['Total'] = chennai[[ 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM']].sum(axis=1)

# %%
chennai.sample(5)
# Out:
#            Date  POONDI  CHOLAVARAM  REDHILLS  CHEMBARAMBAKKAM  Year  Month  \
# 2344 2010-06-02  1190.0        98.0    1989.0           2095.0  2010      6
# 997  2006-09-24  1516.0       210.0    1162.0           1276.0  2006      9
# 5383 2018-09-27    13.0         8.0     510.0            357.0  2018      9
# 1331 2007-08-24   715.0        61.0    1953.0           1036.0  2007      8
# 854  2006-05-04  1716.0       515.0    2100.0           2141.0  2006      5
#
#        Total
# 2344  5372.0
# 997   4164.0
# 5383   888.0
# 1331  3765.0
# 854   6472.0

# %%
Yearwise = chennai.groupby('Year',as_index=False).mean()

# %%
plt.figure(figsize=(9,4))
sns.barplot(x = 'Year',y = 'Total', data = Yearwise)
plt.title('Mean Yearly Water level in all the four reservoir')
plt.show()

# %%
Yearwise.plot(x = 'Year', y = [ 'POONDI', 'CHOLAVARAM', 'REDHILLS', 'CHEMBARAMBAKKAM'], figsize= (15,6) )
# Out:
# <Axes: xlabel='Year'>

# %%
jan = chennai[chennai['Month'] == 1]
plt.figure(figsize=(20,7))
sns.barplot(x = 'Year', y = 'Total', data = jan)
# Out:
# <Axes: xlabel='Year', ylabel='Total'>
